# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
alumnos=[1,2,3,4,5,1,2,3,1,2]
a=[1,2,3,4,5,1,2,3,1,2]

# %%
table=pd.DataFrame(alumnos)

# %%
len(alumnos)
# Out:
# 10

# %%
plt.pie(alumnos)
# Out:
# ([<matplotlib.patches.Wedge at 0x1deea98ee50>,
# ...
#  [Text(1.0905893469510741, 0.14357881569657108, ''),
#   Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(0.42095175181414146, 1.0162674956155027, ''),
#   Text(-0.55000003716311, 0.95262792270675, ''),
#   Text(-1.0905893419100163, -0.14357885398719986, ''),
#   Text(-0.6696375480783815, -0.8726886926066898, ''),
#   Text(-0.28470090816270954, -1.0625184200244853, ''),
#   Text(0.4209518231765126, -1.0162674660562396, ''),
#   Text(0.872688708280688, -0.6696375276516277, ''),
#   Text(1.062518426688391, -0.2847008832926703, '')])

# %%
df=pd.read_csv("dataframe/DNase.csv", delimiter=",",decimal=".",encoding="utf-8")

# %%
df.head()
df.std()
# Out:
# Unnamed: 0    50.950957
# Run            3.171300
# conc           4.059865
# density        0.595573
# dtype: float64

# %%
df['density'] = pd.Categorical(df['density'])

# %%
tabla = pd.crosstab(index=df['density'],columns='total')
tabla

plt.bar(tabla.index,tabla['total'])
# Out:
# <BarContainer object of 161 artists>

# %% [markdown]
# (pd.crosstab(index = Alumnos['edades'], columns = 'count')) / (pd.crosstab(index = Alumnos['edades'], columns = 'count')).sum()
#
# Con una sola instrucción, definid la tabla bidimensional conjunta de frecuencias absolutas de dos vectores llamados "altura" y "peso", de forma que las filas correspondan a "altura" y las columnas a "peso"
#
# tabla3 = pd.crosstab(index = Alumnos['altura'], columns = Alumnos['peso'])
#
# Con una sola instrucción, definid la tabla bidimensional conjunta de frecuencias relativas calculadas dentro del total, de dos vectores llamados "edad" y "altura", de forma que las filas correspondan a "altura" y las columnas a "edad"
#
# (pd.crosstab(index = Alumnos['altura'], columns = Alumnos['edad'])) / (pd.crosstab(index = Alumnos['altura'], columns = Alumnos['edad'])).loc['total']
#
# Con una sola instrucción, dibujad un diagrama de barras básico de un vector llamado "edad"
#
# plt.bar(edad, facecolor='red', edgecolor='black')
#
# Con una sola instrucción, dibujad un diagrama circular básico de un vector llamado "alumnos"
#
# plt.pie(alumnos, explode=0.05, wedgeprops = {'linewidth': 1, 'edgecolor' : 'black'}, startangle=90)
#
# La tabla "DNase" es uno de los data frames que tiene predefinidos R. Dad la instrucción que dibuje un diagrama de barras básico de la variable "density" de este mismo data frame
#
# # cargar el dataframe
#
# df = pd.read_csv("../../data/DNase.csv")
#
#
#
# # pasamos la variable a categótica
#
# df['density'] = pd.Categorical(df['density'])
#
#
#
# # creamos la tabla de frecuencias
#
# tab = pd.crosstab(index = df['density'], columns = 'frecuencia')
#
#
#
# # dibujamos el gráfico
#
# plt.bar(tab.index, tab['frecuencia'], width=0.03, facecolor='red', edgecolor='black')
#
# plt.xlabel('Densidad', fontstyle='italic', weight='normal', fontsize=15)
#
# plt.ylabel('Frecuencia', fontstyle='italic', weight='normal', fontsize=15)
#
# plt.xticks(fontsize='large')
#
# plt.yticks(fontsize='large')
#
# plt.show()
