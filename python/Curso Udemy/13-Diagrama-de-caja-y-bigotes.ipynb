# %% [markdown]
# # Boxplot - Diagrama de cajas y Bigotes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(19880519)

# %%
dist1=100*np.random.rand(50) #da 50 numeros entre 0 y 1
dist2=50*np.ones(25)
dist3= 100+100*np.random.rand(10)
dist4= -100*np.random.rand(10)
data = np.concatenate((dist1,dist2,dist3,dist4))

# %%
fig1, ax1= plt.subplots()
ax1.set_title("Boxplot basico")
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247867cb3d0>,
#   <matplotlib.lines.Line2D at 0x247867cb730>],
#  'caps': [<matplotlib.lines.Line2D at 0x247867cba90>,
#   <matplotlib.lines.Line2D at 0x247867cbdf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x247867cb070>],
#  'medians': [<matplotlib.lines.Line2D at 0x247867d3190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247867d3490>],
#  'means': []}

# %%
fig2, ax2= plt.subplots()
ax2.set_title("Boxplot con muescas")
ax2.boxplot(data, notch = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24787df9100>,
#   <matplotlib.lines.Line2D at 0x24787df9730>],
#  'caps': [<matplotlib.lines.Line2D at 0x24787df92e0>,
#   <matplotlib.lines.Line2D at 0x24787b2c8b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24787e04be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24787b1bd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24787b18f70>],
#  'means': []}

# %%
green_diamond=dict(markerfacecolor="g", marker="D")
fig3, ax3= plt.subplots()
ax3.set_title("Boxplot basico")
ax3.boxplot(data,flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24787cda580>,
#   <matplotlib.lines.Line2D at 0x24787c1ce50>],
#  'caps': [<matplotlib.lines.Line2D at 0x24787cd1e80>,
#   <matplotlib.lines.Line2D at 0x247882216d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x247883ba2b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24788221d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24788154910>],
#  'means': []}

# %%
fig4, ax4= plt.subplots()
ax4.set_title("Boxplot sin OUTLIERS")
ax4.boxplot(data, showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24787761430>,
#   <matplotlib.lines.Line2D at 0x24787761a30>],
#  'caps': [<matplotlib.lines.Line2D at 0x24787b42130>,
#   <matplotlib.lines.Line2D at 0x24787ccb130>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24788144b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x24787b91340>],
#  'fliers': [],
#  'means': []}

# %%
red_square = dict(markerfacecolor="r",marker="s")
fig5, ax5= plt.subplots()
ax5.set_title("Boxplot personalizado,con bigotes chicos y horizontal")
ax5.boxplot(data, vert=False, flierprops=red_square, whis=0.75)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24787a088e0>,
#   <matplotlib.lines.Line2D at 0x24787d61670>],
#  'caps': [<matplotlib.lines.Line2D at 0x247876aa640>,
#   <matplotlib.lines.Line2D at 0x24787be45b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24787d49370>],
#  'medians': [<matplotlib.lines.Line2D at 0x24787be4880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24787be4940>],
#  'means': []}

# %%
dist1=100*np.random.rand(50) #da 50 numeros entre 0 y 1
dist2= 40*np.ones(25)
dist3= 100+100*np.random.rand(10)
dist4= -100*np.random.rand(10)
data2=np.concatenate((dist1,dist2,dist3,dist4))

# %%
data.shape=(-1,1)
data2.shape=(-1,1)

# %%
data
# Out:
# array([[ 95.01724869],
#        [ 69.12380733],
#        [  0.48968187],
#        [ 47.05894682],
#        [  4.67473068],
#        [ 40.67623396],
#        [ 64.21756915],
#        [ 80.53317201],
#        [ 84.53778094],
#        [ 76.21458325],
#        [ 28.2380596 ],
#        [ 54.32356712],
#        [ 21.16504806],
#        [ 52.59957334],
#        [ 65.78326666],
#        [ 54.08796086],
#        [ 65.67253313],
#        [ 51.64959973],
#        [  9.65024989],
#        [ 26.83019698],
#        [ 14.21042473],
#        [ 13.33719378],
#        [ 18.38719552],
#        [ 13.45049344],
#        [ 97.07057711],
#        [ 18.73437919],
#        [ 39.92258068],
#        [ 12.73583334],
#        [ 34.15880868],
#        [ 27.34334446],
#        [ 63.40891363],
#        [ 36.87074717],
#        [ 33.79820623],
#        [ 21.86138707],
#        [ 17.0335533 ],
#        [ 38.27908563],
#        [  4.80311074],
#        [ 36.92550198],
#        [ 51.52779024],
#        [ 97.34127621],
#        [ 32.06991078],
#        [ 64.89984571],
#        [ 59.66134846],
#        [ 48.30605468],
#        [  0.8439178 ],
#        [ 37.71842933],
#        [ 88.4417325 ],
#        [ 72.57061663],
#        [ 90.17827533],
#        [ 21.40222012],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [ 50.        ],
#        [152.12564387],
#        [159.53092968],
#        [128.24711871],
#        [161.46335708],
#        [119.74804423],
#        [123.07403083],
#        [187.28301266],
#        [108.50690613],
#        [171.37788628],
#        [138.51984808],
#        [-90.21203423],
#        [-11.21848891],
#        [-58.83305068],
#        [-20.42825891],
#        [-33.45777572],
#        [-81.12987221],
#        [-61.30977143],
#        [-78.75615113],
#        [-89.19223415],
#        [-21.69129016]])

# %%
fulldata = [data,data2, data2[::2,0]]

# %%
fulldata
# Out:
# [array([[ 95.01724869],
#         [ 69.12380733],
#         [  0.48968187],
#         [ 47.05894682],
#         [  4.67473068],
#         [ 40.67623396],
#         [ 64.21756915],
#         [ 80.53317201],
#         [ 84.53778094],
#         [ 76.21458325],
#         [ 28.2380596 ],
#         [ 54.32356712],
#         [ 21.16504806],
#         [ 52.59957334],
#         [ 65.78326666],
#         [ 54.08796086],
#         [ 65.67253313],
#         [ 51.64959973],
#         [  9.65024989],
#         [ 26.83019698],
#         [ 14.21042473],
#         [ 13.33719378],
#         [ 18.38719552],
#         [ 13.45049344],
#         [ 97.07057711],
#         [ 18.73437919],
#         [ 39.92258068],
#         [ 12.73583334],
#         [ 34.15880868],
#         [ 27.34334446],
#         [ 63.40891363],
#         [ 36.87074717],
#         [ 33.79820623],
#         [ 21.86138707],
#         [ 17.0335533 ],
#         [ 38.27908563],
#         [  4.80311074],
#         [ 36.92550198],
#         [ 51.52779024],
#         [ 97.34127621],
#         [ 32.06991078],
#         [ 64.89984571],
#         [ 59.66134846],
#         [ 48.30605468],
#         [  0.8439178 ],
#         [ 37.71842933],
#         [ 88.4417325 ],
#         [ 72.57061663],
#         [ 90.17827533],
#         [ 21.40222012],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [ 50.        ],
#         [152.12564387],
#         [159.53092968],
#         [128.24711871],
#         [161.46335708],
#         [119.74804423],
#         [123.07403083],
#         [187.28301266],
#         [108.50690613],
#         [171.37788628],
#         [138.51984808],
#         [-90.21203423],
#         [-11.21848891],
#         [-58.83305068],
#         [-20.42825891],
#         [-33.45777572],
#         [-81.12987221],
#         [-61.30977143],
#         [-78.75615113],
#         [-89.19223415],
#         [-21.69129016]]),
#  array([[ 31.16973912],
#         [ 46.70100876],
#         [ 26.60993688],
#         [ 79.00773255],
#         [ 90.56672944],
#         [ 91.73344957],
#         [ 61.03538679],
#         [ 86.62796609],
#         [ 97.18490404],
#         [ 61.45512778],
#         [ 17.14542917],
#         [ 16.10378587],
#         [ 96.59853259],
#         [ 96.17832253],
#         [ 92.46883514],
#         [ 50.91704958],
#         [ 49.96398171],
#         [ 53.52049445],
#         [  4.0038454 ],
#         [ 31.62828316],
#         [ 31.87410909],
#         [ 48.333707  ],
#         [ 21.32083179],
#         [ 48.12846986],
#         [ 99.48323968],
#         [ 24.95000794],
#         [ 65.11671844],
#         [  1.3590582 ],
#         [  8.43531747],
#         [ 48.38046798],
#         [ 37.24106542],
#         [ 81.74682661],
#         [ 75.66841362],
#         [ 39.00937993],
#         [ 93.52469242],
#         [ 65.61157033],
#         [ 15.01880994],
#         [ 42.09380234],
#         [ 40.19375558],
#         [ 45.89231952],
#         [ 69.12420345],
#         [ 71.55040482],
#         [ 65.3823683 ],
#         [ 14.53332426],
#         [  6.94667025],
#         [ 84.56070612],
#         [  9.32278803],
#         [ 55.62053867],
#         [ 34.86982473],
#         [ 60.30033786],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [ 40.        ],
#         [103.49593088],
#         [105.87942329],
#         [127.31998555],
#         [107.49013385],
#         [196.46197876],
#         [102.14149696],
#         [168.23704473],
#         [150.40758612],
#         [160.05348904],
#         [133.78400788],
#         [-53.06158121],
#         [-54.87542598],
#         [-53.45636736],
#         [-18.05516401],
#         [ -3.8160298 ],
#         [-60.26200247],
#         [ -3.48314714],
#         [-36.83193855],
#         [-45.78419459],
#         [-75.2947361 ]]),
#  array([ 31.16973912,  26.60993688,  90.56672944,  61.03538679,
#          97.18490404,  17.14542917,  96.59853259,  92.46883514,
#          49.96398171,   4.0038454 ,  31.87410909,  21.32083179,
#          99.48323968,  65.11671844,   8.43531747,  37.24106542,
#          75.66841362,  93.52469242,  15.01880994,  40.19375558,
#          69.12420345,  65.3823683 ,   6.94667025,   9.32278803,
#          34.86982473,  40.        ,  40.        ,  40.        ,
#          40.        ,  40.        ,  40.        ,  40.        ,
#          40.        ,  40.        ,  40.        ,  40.        ,
#          40.        ,  40.        , 105.87942329, 107.49013385,
#         102.14149696, 150.40758612, 133.78400788, -54.87542598,
#         -18.05516401, -60.26200247, -36.83193855, -75.2947361 ])]

# %%
fig6, ax6= plt.subplots()
ax6.set_title("Boxplot Multiple de muestras diferente naturaleza")
ax6.boxplot(fulldata)
plt.show()
