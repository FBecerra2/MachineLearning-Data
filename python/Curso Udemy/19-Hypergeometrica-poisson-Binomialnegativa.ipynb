# %% [markdown]
# ## Distribucion HyperGeometrica
# scipy.stats.hypergeom
#
# pmf(k,M,n,N)
#
# cdf(k,M,n,N)
#
# ppf(q,M,n,N)
#
# rvs(M,n,N)
#
# M= el nuemro de objetos del primer tipo
# N= el numero de objetos del segundo tipo
# n= el numero de extracciones realizadas

# %%
from scipy.stats import hypergeom
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
[M,n,N]=[20, 7, 12]
rv=hypergeom(M,n,N)
x=np.arange(0,n+1)
y=rv.pmf(x)


mean, var, skew, kurt = rv.stats(moments='mvsk')
print("Media %f" %mean)
print("Varianza %f" %var)
print("Sesgo %f" %skew)
print("Curtosis %f" %kurt)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,'bo')
ax.vlines(x,0,y,lw=2, alpha=0.5)
ax.set_xlabel("Numero de prros entre los 12 elegidos al azar")
ax.set_ylabel("Distribucion de probabilidad de  H(13,7,12)")
plt.show()
# Out:
# Media 4.200000
# Varianza 1.149474
# Sesgo -0.062181
# Curtosis -0.152661

# %% [markdown]
# ## Distribucion de Poisson
#
# Frecuandia por unidad de medida, cuantas personas entran a una tienda en una hora

# %%
from scipy.stats import poisson
fig, ax=plt.subplots(1,1)
mu=0.8 # cada 10 paginas 8 errores

mean, var , skew,kurt=poisson.stats(mu,moments='mvsk')
x=np.arange(0,5)

print("Media %f" %mean)
print("Varianza %f" %var)
print("Sesgo %f" %skew)
print("Curtosis %f" %kurt)


ax.plot(x,poisson.pmf(x,mu),'bo',ms=8,label="Poisson(0.08")
ax.vlines(x,0,poisson.pmf(x,mu),colors='b',lw=4,alpha=0.5)
ax.legend(loc='best',frameon=False)
plt.show()
# Out:
# Media 0.800000
# Varianza 0.800000
# Sesgo 1.118034
# Curtosis 1.250000

# %% [markdown]
# ## Distribucion Binomial Negativa
#
# repetir bernoulli asta obtener N numero de Exitos
#
#
# tener dos cajas de cigarrillos e ir fumando aleatoriamente de una u otra caja, y ver la probabilidad de cuantos debo fumar para vaciar una caja.
# scipy.stats.nbinom
#
# pmf(k,n,p)
#
# cdf(k,n,p)
#
# ppf(q,n,p)
#
# rvs(n,p)
#
# Donde n es el numero de casos de exitos y p la probabilidad del exito
